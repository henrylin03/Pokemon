# %% [markdown]
# # Pokemon
# Using SQL & Python to analyse Pokemon data ([Kaggle](https://www.kaggle.com/abcsds/pokemon)).
# git
# **Please see the [README](https://github.com/henrylin03/Pokemon_EDA/blob/main/README.md) for more information.**

# %% [markdown]
# ## Setup
# ### Importing packages

# %%
import pandas as pd
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Reading in CSV & creating SQL database

# %%
df = pd.read_csv('input/Pokemon.csv')
# df.head()

# %%
engine = create_engine('sqlite://', echo=False)

df.to_sql('pokemon', engine, if_exists='replace', index=False)

# %% [markdown]
# ## Inspecting & Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %% [markdown]
# Cleaning column names by:
# 1. Removing spaces and dots, and
# 2. Describing "#" as the "National Pokedex number"

# %%
df.columns = df.columns\
                .str.replace(' ', '')\
                .str.replace('.', '')\
                .str.replace('#', 'NdexID')

print(df.columns)

# replace SQL database:
df.to_sql('pokemon', engine, if_exists='replace', index=False)
# Out:
# Index(['NdexID', 'Name', 'Type1', 'Type2', 'Total', 'HP', 'Attack', 'Defense',
#        'SpAtk', 'SpDef', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')
# <ipython-input-5-20c32ad60880>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df.columns = df.columns\

# %% [markdown]
# Number of rows:

# %%
pd.read_sql_query("""SELECT COUNT(*) row_count 
                     FROM pokemon""", engine)
# Out:
#    row_count
# 0        800

# %% [markdown]
# First 5 rows:

# %%
pd.read_sql_query("""SELECT * 
                     FROM pokemon 
                     LIMIT 5""", engine)
# Out:
#    NdexID                   Name  Type1   Type2  Total  HP  Attack  Defense  \
# 0       1              Bulbasaur  Grass  Poison    318  45      49       49
# 1       2                Ivysaur  Grass  Poison    405  60      62       63
# 2       3               Venusaur  Grass  Poison    525  80      82       83
# 3       3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4       4             Charmander   Fire    None    309  39      52       43
#
#    SpAtk  SpDef  Speed  Generation  Legendary
# 0     65     65     45           1          0
# 1     80     80     60           1          0
# 2    100    100     80           1          0
# 3    122    120     80           1          0
# 4     60     50     65           1          0

# %% [markdown]
# ### Missing

# %%
df.isna().sum()
# Out:
# NdexID          0
# Name            0
# Type1           0
# Type2         386
# Total           0
# HP              0
# Attack          0
# Defense         0
# SpAtk           0
# SpDef           0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
df[df.isnull().any(axis=1)].sort_values('Name')
# Out:
#      NdexID               Name     Type1 Type2  Total  HP  Attack  Defense  \
# 68       63               Abra   Psychic   NaN    310  25      20       15
# 392     359              Absol      Dark   NaN    465  65     130       60
# 393     359    AbsolMega Absol      Dark   NaN    565  65     150       60
# 678     617           Accelgor       Bug   NaN    495  80      70       40
# 333     306  AggronMega Aggron     Steel   NaN    630  70     140      230
# ..      ...                ...       ...   ...    ...  ..     ...      ...
# 367     335           Zangoose    Normal   NaN    458  73     115       60
# 582     523          Zebstrika  Electric   NaN    497  75     100       63
# 286     263          Zigzagoon    Normal   NaN    240  38      30       41
# 632     571            Zoroark      Dark   NaN    510  60     105       60
# 631     570              Zorua      Dark   NaN    330  40      65       40
#
#      SpAtk  SpDef  Speed  Generation  Legendary
# 68     105     55     90           1      False
# 392     75     60     75           3      False
# 393    115     60    115           3      False
# 678    100     60    145           5      False
# 333     60     80     50           3      False
# ..     ...    ...    ...         ...        ...
# 367     60     60     90           3      False
# 582     80     63    116           5      False
# 286     30     41     60           3      False
# 632    120     60    105           5      False
# 631     80     40     65           5      False
#
# [386 rows x 13 columns]

# %% [markdown]
# Because `Type 2` represents secondary types of Pokemons, with many Pokemons only being assigned a primary type (`Type 1`), this value cannot be imputed. A Pokemon's secondary type (if any) is an important attribute for the Pokemon's moves, and thus should not be removed.

# %% [markdown]
# Finding 'Glitch' type or '???' type Pokemons (e.g. Arceus):

# %%
pd.read_sql_query("""SELECT * 
                     FROM pokemon
                     WHERE Type1 = '???'
                         OR Type1 LIKE '%glitch%'
                         OR Name = 'Arceus'""", engine)
# Out:
#    NdexID    Name   Type1 Type2  Total   HP  Attack  Defense  SpAtk  SpDef  \
# 0     493  Arceus  Normal  None    720  120     120      120    120    120
#
#    Speed  Generation  Legendary
# 0    120           4          1

# %% [markdown]
# ### Duplication
# Checking for duplicated Pokemon names:

# %%
pd.read_sql_query("""SELECT name,
                         COUNT(*) count
                     FROM pokemon
                     GROUP BY 1
                     HAVING count > 1""", engine)
# Out:
# Empty DataFrame
# Columns: [Name, count]
# Index: []

# %% [markdown]
# ### Concatenating Primary & Secondary Types, where available
# From above, some Pokemons have a secondary type (`Type2`), which is an important attribute that differentiate them from Pokemons with the same primary type (`Type1`) in terms of available moves and weaknesses.

# %%
df['TypeConcat'] = df[['Type1', 'Type2']]\
                    .apply(lambda x:
                           '{}-{}'.format(x[0],x[1])
                           if pd.notnull(x[1])
                           else x[0],
                           axis=1)

df.TypeConcat
# Out:
# 0       Grass-Poison
# 1       Grass-Poison
# 2       Grass-Poison
# 3       Grass-Poison
# 4               Fire
#            ...
# 795       Rock-Fairy
# 796       Rock-Fairy
# 797    Psychic-Ghost
# 798     Psychic-Dark
# 799       Fire-Water
# Name: TypeConcat, Length: 800, dtype: object

# %% [markdown]
# Replacing existing SQL database:

# %%
df.to_sql('pokemon', engine, if_exists='replace', index=False)

# %% [markdown]
# ## Insights

# %% [markdown]
# ### Pokemon types

# %% [markdown]
# #### Top 10 Strongest Pokemon types - Primary & Secondary Types combined

# %%
pd.read_sql_query("""SELECT TypeConcat Type,
                         ROUND(
                             AVG(Total), 1
                         ) AvgTotalStats,
                         COUNT(*) Count
                     FROM pokemon
                     GROUP BY 1
                     ORDER BY 2 DESC
                     LIMIT 10""", engine)
# Out:
#               Type  AvgTotalStats  Count
# 0      Ground-Fire          770.0      1
# 1       Dragon-Ice          686.7      3
# 2     Steel-Dragon          680.0      1
# 3     Psychic-Dark          680.0      1
# 4     Ghost-Dragon          680.0      2
# 5      Dragon-Fire          680.0      1
# 6  Dragon-Electric          680.0      1
# 7        Rock-Dark          650.0      2
# 8   Dragon-Psychic          650.0      4
# 9    Dragon-Flying          641.7      6

# %% [markdown]
# Excluding Legendary & Mega Evolution Pokemons:

# %%
pd.read_sql_query("""SELECT TypeConcat Type,
                         ROUND(
                             AVG(Total), 1
                         ) AvgTotalStats,
                         COUNT(*) Count
                     FROM pokemon
                     WHERE Legendary = 0
                         AND Name NOT LIKE '%Mega %'
                     GROUP BY 1
                     ORDER BY 2 DESC
                     LIMIT 10""", engine)
# Out:
#               Type  AvgTotalStats  Count
# 0        Rock-Dark          600.0      1
# 1    Psychic-Grass          600.0      1
# 2  Normal-Fighting          600.0      1
# 3    Dragon-Flying          563.3      3
# 4   Water-Fighting          556.7      3
# 5     Water-Dragon          540.0      1
# 6     Fire-Psychic          537.0      2
# 7      Water-Steel          530.0      1
# 8   Normal-Psychic          527.5      2
# 9     Grass-Ground          525.0      1

# %% [markdown]
# Note that the sample size is quite small for each concatenated type.

# %% [markdown]
# #### By Primary Type only

# %% [markdown]
# By Primary Type:

# %%
strongest_type = pd.read_sql_query("""
                    SELECT Type1,
                        ROUND(
                            AVG(total), 1
                        ) AvgTotalStats,
                        COUNT(*) Count
                    FROM pokemon
                    GROUP BY 1 
                    ORDER BY 2 DESC""", engine)
strongest_type
# Out:
#        Type1  AvgTotalStats  Count
# 0     Dragon          550.5     32
# 1      Steel          487.7     27
# 2     Flying          485.0      4
# 3    Psychic          475.9     57
# 4       Fire          458.1     52
# 5       Rock          453.8     44
# 6       Dark          445.7     31
# 7   Electric          443.4     44
# 8      Ghost          439.6     32
# 9     Ground          437.5     32
# 10       Ice          433.5     24
# 11     Water          430.5    112
# 12     Grass          421.1     70
# 13  Fighting          416.4     27
# 14     Fairy          413.2     17
# 15    Normal          401.7     98
# 16    Poison          399.1     28
# 17       Bug          378.9     69

# %% [markdown]
# Visualising distribution of `Total` stats for Primary Types:

# %%
plt.figure(figsize=(20,8))

type1_stats = sns.boxplot(data=df, x='Type1', y='Total')
type1_stats.axes.set_title('Total Stats for Primary Types', fontsize=15)
type1_stats.set_xlabel('Primary Type', fontsize=15)
type1_stats.set_ylabel('Total Stats', fontsize=15)
type1_stats.tick_params(labelsize=15)

plt.tight_layout()

plt.show()

# %% [markdown]
# ### Generations

# %% [markdown]
# #### Have Pokemons become more powerful with newer Generations?

# %% [markdown]
# Note that in Generation 6, "Mega Evolutions" were introduced, but are recorded as earlier Generations in the `pokemon` dataset here.
#
# Mega Evolved Pokemons have +100 `Total` stat points and could overestimate earlier Generations' Pokemon stats.

# %%
pd.read_sql_query("""SELECT Generation,
                         ROUND(
                             AVG(total), 1
                         ) AvgTotalStats
                     FROM pokemon
                     GROUP BY 1
                     ORDER BY 2 DESC""", engine)
# Out:
#    Generation  AvgTotalStats
# 0           4          459.0
# 1           6          436.4
# 2           3          436.2
# 3           5          435.0
# 4           1          426.8
# 5           2          418.3

# %% [markdown]
# Visualised:

# %%
plt.figure(figsize=(12,8))

violin = sns.violinplot(x=df['Generation'], y=df['Total'])
violin.set_title('Avg "Total" Stats of Pokemons Over Generations')

plt.show()

# %% [markdown]
# Excluding Mega Evolution Pokemons:

# %%
pd.read_sql_query("""SELECT Generation,
                         ROUND(
                             AVG(total), 1
                         ) AvgTotalStats
                     FROM pokemon
                     WHERE Name NOT LIKE '%Mega %'
                     GROUP BY 1
                     ORDER BY 2 DESC""", engine)
# Out:
#    Generation  AvgTotalStats
# 0           4          451.9
# 1           5          434.3
# 2           6          433.1
# 3           3          411.6
# 4           1          407.1
# 5           2          406.2

# %% [markdown]
# #### Top 3 Strongest Pokemons (by `Total` stats) of each generation

# %%
pd.read_sql_query("""SELECT *
                     FROM (
                         SELECT
                             Generation,
                             RANK() OVER (
                                 PARTITION BY Generation
                                 ORDER BY Total DESC
                             ) Rank,
                             Name,
                             CASE 
                                 WHEN Legendary = 1 THEN "Yes" ELSE "No" 
                             END Legendary,
                             Total,
                             HP,
                             Attack Atk,
                             Defense Def,
                             SpAtk,
                             SpDef,
                             Speed
                         FROM pokemon
                     )
                     WHERE Rank <= 3
                     ORDER BY Generation, Rank""", engine)
# Out:
#     Generation  Rank                     Name Legendary  Total   HP  Atk  Def  \
# 0            1     1      MewtwoMega Mewtwo X       Yes    780  106  190  100
# 1            1     1      MewtwoMega Mewtwo Y       Yes    780  106  150   70
# 2            1     3                   Mewtwo       Yes    680  106  110   90
# 3            2     1  TyranitarMega Tyranitar        No    700  100  164  150
# 4            2     2                    Lugia       Yes    680  106   90  130
# 5            2     2                    Ho-oh       Yes    680  106  130   90
# 6            3     1    RayquazaMega Rayquaza       Yes    780  105  180  100
# 7            3     2      KyogrePrimal Kyogre       Yes    770  100  150   90
# 8            3     2    GroudonPrimal Groudon       Yes    770  100  180  160
# 9            4     1                   Arceus       Yes    720  120  120  120
# 10           4     2    GarchompMega Garchomp        No    700  108  170  115
# 11           4     3                   Dialga       Yes    680  100  120  120
# 12           4     3                   Palkia       Yes    680   90  120  100
# 13           4     3    GiratinaAltered Forme       Yes    680  150  100  120
# 14           4     3     GiratinaOrigin Forme       Yes    680  150  120  100
# 15           5     1       KyuremBlack Kyurem       Yes    700  125  170  100
# 16           5     1       KyuremWhite Kyurem       Yes    700  125  120   90
# 17           5     3                 Reshiram       Yes    680  100  120  100
# 18           5     3                   Zekrom       Yes    680  100  150  120
# 19           6     1      DiancieMega Diancie       Yes    700   50  160  110
# 20           6     2                  Xerneas       Yes    680  126  131   95
# 21           6     2                  Yveltal       Yes    680  126  131   95
# 22           6     2       HoopaHoopa Unbound       Yes    680   80  160   60
#
#     SpAtk  SpDef  Speed
# 0     154    100    130
# 1     194    120    140
# 2     154     90    130
# 3      95    120     71
# 4      90    154    110
# 5     110    154     90
# 6     180    100    115
# 7     180    160     90
# 8     150     90     90
# 9     120    120    120
# 10    120     95     92
# 11    150    100     90
# 12    150    120    100
# 13    100    120     90
# 14    120    100     90
# 15    120     90     95
# 16    170    100     95
# 17    150    120     90
# 18    120    100     90
# 19    160    110    110
# 20    131     98     99
# 21    131     98     99
# 22    170    130     80

# %% [markdown]
# Excluding Mega Evolutions:

# %%
pd.read_sql_query("""SELECT *
                     FROM (
                         SELECT
                             Generation,
                             RANK() OVER (
                                 PARTITION BY Generation
                                 ORDER BY Total DESC
                             ) Rank,
                             Name,
                             CASE 
                                 WHEN Legendary = 1 THEN "Yes" ELSE "No" 
                             END Legendary,
                             Total,
                             HP,
                             Attack Atk,
                             Defense Def,
                             SpAtk,
                             SpDef,
                             Speed
                         FROM pokemon
                         WHERE Name NOT LIKE '%Mega %'
                     )
                     WHERE Rank <= 3
                     ORDER BY Generation, Rank""", engine)
# Out:
#     Generation  Rank                   Name Legendary  Total   HP  Atk  Def  \
# 0            1     1                 Mewtwo       Yes    680  106  110   90
# 1            1     2              Dragonite        No    600   91  134   95
# 2            1     2                    Mew        No    600  100  100  100
# 3            2     1                  Lugia       Yes    680  106   90  130
# 4            2     1                  Ho-oh       Yes    680  106  130   90
# 5            2     3              Tyranitar        No    600  100  134  110
# 6            2     3                 Celebi        No    600  100  100  100
# 7            3     1    KyogrePrimal Kyogre       Yes    770  100  150   90
# 8            3     1  GroudonPrimal Groudon       Yes    770  100  180  160
# 9            3     3               Rayquaza       Yes    680  105  150   90
# 10           4     1                 Arceus       Yes    720  120  120  120
# 11           4     2                 Dialga       Yes    680  100  120  120
# 12           4     2                 Palkia       Yes    680   90  120  100
# 13           4     2  GiratinaAltered Forme       Yes    680  150  100  120
# 14           4     2   GiratinaOrigin Forme       Yes    680  150  120  100
# 15           5     1     KyuremBlack Kyurem       Yes    700  125  170  100
# 16           5     1     KyuremWhite Kyurem       Yes    700  125  120   90
# 17           5     3               Reshiram       Yes    680  100  120  100
# 18           5     3                 Zekrom       Yes    680  100  150  120
# 19           6     1                Xerneas       Yes    680  126  131   95
# 20           6     1                Yveltal       Yes    680  126  131   95
# 21           6     1     HoopaHoopa Unbound       Yes    680   80  160   60
#
#     SpAtk  SpDef  Speed
# 0     154     90    130
# 1     100    100     80
# 2     100    100    100
# 3      90    154    110
# 4     110    154     90
# 5      95    100     61
# 6     100    100    100
# 7     180    160     90
# 8     150     90     90
# 9     150     90     95
# 10    120    120    120
# 11    150    100     90
# 12    150    120    100
# 13    100    120     90
# 14    120    100     90
# 15    120     90     95
# 16    170    100     95
# 17    150    120     90
# 18    120    100     90
# 19    131     98     99
# 20    131     98     99
# 21    170    130     80

# %% [markdown]
# Excluding Legendary Pokemons and Mega Evolutions:

# %%
pd.read_sql_query("""SELECT *
                     FROM (
                         SELECT
                             Generation,
                             RANK() OVER (
                                 PARTITION BY Generation
                                 ORDER BY Total DESC
                             ) Rank,
                             Name,
                             Total,
                             HP,
                             Attack Atk,
                             Defense Def,
                             SpAtk,
                             SpDef,
                             Speed
                         FROM pokemon
                         WHERE Legendary = 0
                             AND Name NOT LIKE '%Mega %'
                     )
                     WHERE Rank <= 3
                     ORDER BY Generation, Rank""", engine)
# Out:
#     Generation  Rank                     Name  Total   HP  Atk  Def  SpAtk  \
# 0            1     1                Dragonite    600   91  134   95    100
# 1            1     1                      Mew    600  100  100  100    100
# 2            1     3                 Arcanine    555   90  110   80    100
# 3            2     1                Tyranitar    600  100  134  110     95
# 4            2     1                   Celebi    600  100  100  100    100
# 5            2     3                  Kingdra    540   75   95   95     95
# 6            2     3                  Blissey    540  255   10   10     75
# 7            3     1                  Slaking    670  150  160  100     95
# 8            3     2                Salamence    600   95  135   80    110
# 9            3     2                Metagross    600   80  135  130     95
# 10           4     1                 Garchomp    600  108  130   95     80
# 11           4     1                Cresselia    600  120   70  120     75
# 12           4     1                  Manaphy    600  100  100  100    100
# 13           5     1                Hydreigon    600   92  105   90    125
# 14           5     1       MeloettaAria Forme    600  100   77   77    128
# 15           5     1  MeloettaPirouette Forme    600  100  128   90     77
# 16           5     1                 Genesect    600   71  120   95    120
# 17           6     1                   Goodra    600   90  100   70    110
# 18           6     2                  Florges    552   78   65   68    112
# 19           6     3                  Noivern    535   85   70   80     97
#
#     SpDef  Speed
# 0     100     80
# 1     100    100
# 2      80     95
# 3     100     61
# 4     100    100
# 5      95     85
# 6     135     55
# 7      65    100
# 8      80    100
# 9      90     70
# 10     85    102
# 11    130     85
# 12    100    100
# 13     90     98
# 14    128     90
# 15     77    128
# 16     95     99
# 17    150     80
# 18    154     75
# 19     80    123

# %% [markdown]
# #### Which generation had the strongest Legendary Pokemons?

# %% [markdown]
# Excluding Mega Evolutions:

# %%
pd.read_sql_query("""SELECT Generation,
                         ROUND(AVG(Total), 1) AvgTotalStats,
                         ROUND(AVG(HP), 1) AvgHP,
                         ROUND(AVG(Attack), 1) AvgAtk,
                         ROUND(AVG(Defense), 1) AvgDef,
                         ROUND(AVG(SpAtk), 1) AvgSpAtk,
                         ROUND(AVG(SpDef), 1) AvgSpDef,
                         ROUND(AVG(Speed), 1) AvgSpeed,
                         COUNT(*) Count
                     FROM pokemon
                     WHERE Legendary = 1
                         AND Name NOT LIKE '%Mega %'
                     GROUP BY 1
                     ORDER BY 2 DESC""", engine)
# Out:
#    Generation  AvgTotalStats  AvgHP  AvgAtk  AvgDef  AvgSpAtk  AvgSpDef  \
# 0           4          634.6  100.8   109.8   103.5     116.2     103.5
# 1           6          634.3   92.9   120.3   100.1     127.6     113.0
# 2           3          633.3   80.3   114.7   107.3     119.3     112.0
# 3           2          620.0  103.4    99.0    99.0      99.0     119.6
# 4           5          618.7   96.1   120.3    90.7     117.8      92.1
# 5           1          605.0   94.0    96.3    91.3     124.8      97.5
#
#    AvgSpeed  Count
# 0     100.7     13
# 1      80.4      7
# 2      99.7     15
# 3     100.0      5
# 4     101.7     15
# 5     101.3      4
